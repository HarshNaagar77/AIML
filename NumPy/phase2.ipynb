# %% [markdown]
# ## NumPy Array Operations

# %%
import numpy as np

# %%
#slicing
arr = np.array([3, 4,2 ,6 ,4,4 ,7,4])
print(arr[2:5])
# Out:
# [2 6 4]

# %%
#indexing in 2d array
arr2d = np.floor(np.random.random((3,3))* 100)
print(arr2d)

print(arr2d[1,2])    # 2nd index element of index 1 row
print(arr2d[1])      # entire 1st index row
print(arr2d[:,2])   # entire 2nd index column
# Out:
# [[52. 48. 18.]
#  [53. 72. 64.]
#  [90. 26. 79.]]
# 64.0
# [53. 72. 64.]
# [18. 64. 79.]

# %% [markdown]
# ## Sorting

# %%
# 1d array sorting 
print("sorted array:", np.sort(arr))

# 2d array sorting
print("original 2d array:\n", arr2d)
print("sorted 2d array along rows:\n", np.sort(arr2d, axis=1))
print("sorted 2d array along columns:\n", np.sort(arr2d, axis=0))
# Out:
# sorted array: [2 3 4 4 4 4 6 7]
# original 2d array:
#  [[52. 48. 18.]
#  [53. 72. 64.]
#  [90. 26. 79.]]
# sorted 2d array along rows:
#  [[18. 48. 52.]
#  [53. 64. 72.]
#  [26. 79. 90.]]
# sorted 2d array along columns:
#  [[52. 26. 18.]
#  [53. 48. 64.]
#  [90. 72. 79.]]

# %% [markdown]
# ## Filter

# %%
# In numpy , arrays can also use mask i.e expressions for indexing

newArr = np.array([10, 15, 20, 25, 30, 35, 40])
mask = newArr > 25
print(newArr[mask])

# here we passed an expression as index in an array which lead to solving the expression and gave us output
# Out:
# [30 35 40]

# %% [markdown]
# ## Where

# %%
# we can use "where" to implement a condition just like mask

res = np.where(newArr > 20)
print(newArr[res])
# Out:
# [25 30 35 40]

# %%
# we can say that "where" works as if else clause
# here , we write it as 
# if newArr > 20 
# print newArr*2
# else newArr

res2 = np.where( newArr > 20 , newArr * 2 , newArr )
print(res2)
# Out:
# [10 15 20 50 60 70 80]

# %% [markdown]
# ## Array compatibility

# %%
arr3 = np.array([3,4,6])
arr4 = np.array([4,2,6])
arr5 = np.array([2])

print(arr3.shape == arr4.shape)
print(arr3.shape == arr5.shape)
# Out:
# True
# False

# %% [markdown]
# ## Adding elements to an array

# %%
a = np.array([[ 2 ,4 ,5],
             [2,7,1]])
print(a)
addRow = np.vstack((a , np.array([3,1,8]) ))                 # used to add row
print("After adding row :\n" , addRow)

addCol = np.hstack( (a , np.array([[2] , [2]]) ))
print("After adding col :\n" , addCol)
# Out:
# [[2 4 5]
#  [2 7 1]]
# After adding row :
#  [[2 4 5]
#  [2 7 1]
#  [3 1 8]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 7
#       4 addRow = np.vstack((a , np.array([3,1,8]) ))                 # used to add row
#       5 print("After adding row :\n" , addRow)
# ----> 7 addCol = np.hstack( (a , np.array([2] , [2]) ))
#       8 print("After adding col :\n" , addCol)
#
# TypeError: Field elements must be 2- or 3-tuples, got '2'
