# %% [markdown]
# ## Data Cleansing

# %%
import pandas as pd

# %%
df = pd.read_csv('./csv/color2.csv')
df    # Here there will be NAN if some values are missing
# Out:
#      Name      HEX               RGB
# 0   White  #FFFFFF  rgb(100,100,100)
# 1  Silver  #C0C0C0     rgb(75,75,75)
# 2    Gray      NaN     rgb(50,50,50)
# 3   Black  #000000        rgb(0,0,0)
# 4     Red  #FF0000      rgb(100,0,0)
# 5  Maroon  #800000               NaN
# 6  Yellow  #FFFF00    rgb(100,100,0)
# 7     NaN  #808000      rgb(50,50,0)
# 8    Lime  #00FF00      rgb(0,100,0)
# 9   Green  #008000       rgb(0,50,0)

# %%
# Removing Nan Values

df.dropna()
# Out:
#      Name      HEX               RGB
# 0   White  #FFFFFF  rgb(100,100,100)
# 1  Silver  #C0C0C0     rgb(75,75,75)
# 3   Black  #000000        rgb(0,0,0)
# 4     Red  #FF0000      rgb(100,0,0)
# 6  Yellow  #FFFF00    rgb(100,100,0)
# 8    Lime  #00FF00      rgb(0,100,0)
# 9   Green  #008000       rgb(0,50,0)

# %%
# Replacing Nan vlaues with something else
df.fillna(0)
# Out:
#      Name      HEX               RGB
# 0   White  #FFFFFF  rgb(100,100,100)
# 1  Silver  #C0C0C0     rgb(75,75,75)
# 2    Gray        0     rgb(50,50,50)
# 3   Black  #000000        rgb(0,0,0)
# 4     Red  #FF0000      rgb(100,0,0)
# 5  Maroon  #800000                 0
# 6  Yellow  #FFFF00    rgb(100,100,0)
# 7       0  #808000      rgb(50,50,0)
# 8    Lime  #00FF00      rgb(0,100,0)
# 9   Green  #008000       rgb(0,50,0)

# %%
df.rename( columns= {"Name": "Color"}) # changes name of column but not in the original dataframe
# Out:
#     Color      HEX               RGB
# 0   White  #FFFFFF  rgb(100,100,100)
# 1  Silver  #C0C0C0     rgb(75,75,75)
# 2    Gray      NaN     rgb(50,50,50)
# 3   Black  #000000        rgb(0,0,0)
# 4     Red  #FF0000      rgb(100,0,0)
# 5  Maroon  #800000               NaN
# 6  Yellow  #FFFF00    rgb(100,100,0)
# 7     NaN  #808000      rgb(50,50,0)
# 8    Lime  #00FF00      rgb(0,100,0)
# 9   Green  #008000       rgb(0,50,0)

# %%
df.rename( columns={ "Name" : "Color" } , inplace= True)  # changes the name in original dataframe
df
# Out:
#     Color      HEX               RGB
# 0   White  #FFFFFF  rgb(100,100,100)
# 1  Silver  #C0C0C0     rgb(75,75,75)
# 2    Gray      NaN     rgb(50,50,50)
# 3   Black  #000000        rgb(0,0,0)
# 4     Red  #FF0000      rgb(100,0,0)
# 5  Maroon  #800000               NaN
# 6  Yellow  #FFFF00    rgb(100,100,0)
# 7     NaN  #808000      rgb(50,50,0)
# 8    Lime  #00FF00      rgb(0,100,0)
# 9   Green  #008000       rgb(0,50,0)

# %%
df["Color"][1]
# Out:
# 'Silver'

# %%
df = pd.array([ [1 ,2,3],[2,4,2]])
df[1][2]
# Out:
# 2

# %%
len(df)
# Out:
# 10

# %% [markdown]
# ## Add columns

# %%
df["Likes"] = [ i for i in range(len(df))]
df
# Out:
#      Name      HEX               RGB  Likes
# 0   White  #FFFFFF  rgb(100,100,100)      0
# 1  Silver  #C0C0C0     rgb(75,75,75)      1
# 2    Gray      NaN     rgb(50,50,50)      2
# 3   Black  #000000        rgb(0,0,0)      3
# 4     Red  #FF0000      rgb(100,0,0)      4
# 5  Maroon  #800000               NaN      5
# 6  Yellow  #FFFF00    rgb(100,100,0)      6
# 7     NaN  #808000      rgb(50,50,0)      7
# 8    Lime  #00FF00      rgb(0,100,0)      8
# 9   Green  #008000       rgb(0,50,0)      9

# %% [markdown]
# ## Applying functions on Data

# %%
import random
def fun(a):
    return random.randint(1 , 10)

df["Rating"] = df["Likes"].apply(fun)
df
# Out:
#      Name      HEX               RGB  Likes  Rating
# 0   White  #FFFFFF  rgb(100,100,100)      0       5
# 1  Silver  #C0C0C0     rgb(75,75,75)      1       3
# 2    Gray      NaN     rgb(50,50,50)      2      10
# 3   Black  #000000        rgb(0,0,0)      3      10
# 4     Red  #FF0000      rgb(100,0,0)      4       3
# 5  Maroon  #800000               NaN      5       9
# 6  Yellow  #FFFF00    rgb(100,100,0)      6      10
# 7     NaN  #808000      rgb(50,50,0)      7       4
# 8    Lime  #00FF00      rgb(0,100,0)      8       7
# 9   Green  #008000       rgb(0,50,0)      9       2

# %% [markdown]
# ## Exporting

# %%
exp = df.to_csv("csv/export.csv" , index= 0)

imp = pd.read_csv("csv/export.csv")
imp
# Out:
#      Name      HEX               RGB  Likes  Rating
# 0   White  #FFFFFF  rgb(100,100,100)      0       5
# 1  Silver  #C0C0C0     rgb(75,75,75)      1       3
# 2    Gray      NaN     rgb(50,50,50)      2      10
# 3   Black  #000000        rgb(0,0,0)      3      10
# 4     Red  #FF0000      rgb(100,0,0)      4       3
# 5  Maroon  #800000               NaN      5       9
# 6  Yellow  #FFFF00    rgb(100,100,0)      6      10
# 7     NaN  #808000      rgb(50,50,0)      7       4
# 8    Lime  #00FF00      rgb(0,100,0)      8       7
# 9   Green  #008000       rgb(0,50,0)      9       2
