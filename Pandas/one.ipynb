# %% [markdown]
# ## Pandas

# %%
import pandas as pd

# %%
ser = pd.Series([1,2,3,4])
ser.name = 'Num'
print(ser)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# Name: Num, dtype: int64

# %%
arr = pd.array([1,2,3])
arr
# Out:
# <IntegerArray>
# [1, 2, 3]
# Length: 3, dtype: Int64
